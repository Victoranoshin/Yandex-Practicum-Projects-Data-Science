# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Открыть-файл-с-данными-и-изучить-общую-информацию" data-toc-modified-id="Открыть-файл-с-данными-и-изучить-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открыть файл с данными и изучить общую информацию</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Преобразование-данных-в-нужные-типы-и-обработка-пропусков" data-toc-modified-id="Преобразование-данных-в-нужные-типы-и-обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Преобразование данных в нужные типы и обработка пропусков</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Выяснить,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Выяснить,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выяснить, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li><li><span><a href="#Посмотреть,-как-менялись-продажи-по-платформам." data-toc-modified-id="Посмотреть,-как-менялись-продажи-по-платформам.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посмотреть, как менялись продажи по платформам.</a></span></li><li><span><a href="#Взять-данные-за-соответствующий-актуальный-период." data-toc-modified-id="Взять-данные-за-соответствующий-актуальный-период.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Взять данные за соответствующий актуальный период.</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?" data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают?</a></span></li><li><span><a href="#Построить-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам" data-toc-modified-id="Построить-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам</a></span></li><li><span><a href="#Посмотреть,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков" data-toc-modified-id="Посмотреть,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков</a></span><ul class="toc-item"><li><span><a href="#Платформа-PS4" data-toc-modified-id="Платформа-PS4-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Платформа PS4</a></span></li><li><span><a href="#Платформа-XOne" data-toc-modified-id="Платформа-XOne-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Платформа XOne</a></span></li><li><span><a href="#Платформа-3DS" data-toc-modified-id="Платформа-3DS-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Платформа 3DS</a></span></li></ul></li><li><span><a href="#Посмотреть-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?" data-toc-modified-id="Посмотреть-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах?</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Составить-портрет-пользователя-каждого-региона--(NA,-EU,-JP)" data-toc-modified-id="Составить-портрет-пользователя-каждого-региона--(NA,-EU,-JP)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составить портрет пользователя каждого региона  (NA, EU, JP)</a></span><ul class="toc-item"><li><span><a href="#Регион-NA" data-toc-modified-id="Регион-NA-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Регион NA</a></span></li><li><span><a href="#Регион-EU" data-toc-modified-id="Регион-EU-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Регион EU</a></span></li><li><span><a href="#Регион-JP" data-toc-modified-id="Регион-JP-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Регион JP</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1" data-toc-modified-id="Гипотеза-1-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Гипотеза 1</a></span></li><li><span><a href="#Гипотеза-2" data-toc-modified-id="Гипотеза-2-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Гипотеза 2</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры.
#
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы. Вам нужно выявить закономерности, определяющие успешность игры. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# В этом проекте используются данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# # Порядок выполнения проекта

# %% [markdown]
# <b> Шаг 1. Открыть файл с данными и изучите общую информацию </b>
#
# <b>Шаг 2. Подготовить данные</b>
# 1. Заменить названия столбцов (приведите к нижнему регистру);
# 2. Преобразовать данные в нужные типы. Описать, в каких столбцах заменили тип данных и почему;
# 3. Обработать пропуски при необходимости:
#     - Объяснить, почему пропуски заполнены определенным образом или почему не стали это делать;
#     - Описать причины, которые могли привести к пропускам.
#
# 4. Посчитать суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# <b>Шаг 3. Провести исследовательский анализ данных</b>
# 1. Посмотреть, сколько игр выпускалось в разные годы.
# 2. Посмотреть, как менялись продажи по платформам. Выбирать платформы с наибольшими суммарными продажами и построить распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# 3. Взять данные за соответствующий актуальный период. Определить актуальный период. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# 4. Не учитывать в работе данные за предыдущие годы.
# 5. Какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ.
# 6. Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описать результат.
# 7. Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулировать выводы.
# 8. Соотнести выводы с продажами игр на других платформах.
# 9. Посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# <b> Шаг 4. Составить портрет пользователя каждого региона </b>
# Определить для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Описать различия в долях продаж.
# - Самые популярные жанры (топ-5). Пояснить разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# <b> Шаг 5. Проверьте гипотезы </b>
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задать пороговое значение alpha.
# Поясните:
# - Как формулировалась нулевая и альтернативная гипотезы;
# - Какой критерий применили для проверки гипотез и почему.
#
# <b> Шаг 6. Написать общий вывод </b>

# %% [markdown]
# ## Открыть файл с данными и изучить общую информацию

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as stat
import seaborn as sns

# %%
data = pd.read_csv('datasets/games.csv')

# %%
data_shape0 = data.shape[0]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.columns = [x.lower() for x in data.columns]

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# **Вывод:**
# Получили общую информацию о данных. Изменил стиль названий столбцов на Snake Case. В столбцах `name`, `year_of_release`, `critic_score`, `user_score`, `rating` есть пропуски.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Преобразование данных в нужные типы и обработка пропусков

# %%
data = data.dropna(subset =['year_of_release', 'name'])

# %% [markdown]
# В столбцах `year_of_release` и `name` есть пропуски, скорее всего, они появились из-за ошибки ввода данных.
#
# Количество пропусков в столбцах `year_of_release` и `name` небольшое, поэтому строки с пропусками в этих столбцах можно удалить.

# %%
data.loc[data['user_score'].str.isalpha() ==True, 'user_score'] = np.nan

# %%
data = data.astype({'year_of_release': 'int64'}, errors='ignore')

# %%
data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Значения `tbd`в столбце `user_score` можно заменить на значение `Nan`, поскольку скорее всего это аббревиатура от английского To Be Determined (будет определено).
#
# Нужно заменить тип данных в столбце `year_of_release`, поскольку год выпуска игры может быть только целым числом.
#
# Также необходимо заменить тип данных в столбце `user_score` на `float`, поскольку рейтинг является дробным числом.

# %% [markdown]
# Не будем заполнять пропуски в столбцах `critic_score` и `user_score`, поскольку на значения в этих столбцах может влиять множество факторов, оценить которые довольно трудно. Пропуски в столбце `rating` могли появится, поскольку рейтинговое агентство американское, следовательно, количество оценённых игр, не созданных в США, меньше.

# %%
data['rating'] = data['rating'].fillna('no_information')

# %% [markdown]
# Пропуски в столбце `rating` заполним строкой 'no_information'.

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating                0
# dtype: int64

# %%
1 - data.shape[0] / data_shape0
# Out:
# 0.016212982351181626

# %%
data['sum_sales'] = data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# <b>Найдем неявные дубликаты.

# %%
np.sort(data['platform'].unique())
# Out:
# array(['2600', '3DO', '3DS', 'DC', 'DS', 'GB', 'GBA', 'GC', 'GEN', 'GG',
#        'N64', 'NES', 'NG', 'PC', 'PCFX', 'PS', 'PS2', 'PS3', 'PS4', 'PSP',
#        'PSV', 'SAT', 'SCD', 'SNES', 'TG16', 'WS', 'Wii', 'WiiU', 'X360',
#        'XB', 'XOne'], dtype=object)

# %% [markdown]
# Явных дубликатов в столбце `platform` нет.

# %%
np.sort(data['rating'].unique())
# Out:
# array(['AO', 'E', 'E10+', 'EC', 'K-A', 'M', 'RP', 'T', 'no_information'],
#       dtype=object)

# %% [markdown]
# Явных дубликатов в столбце `platform` нет.

# %% [markdown]
# <b> Найдем явные дубликаты.

# %%
duplicates = data.loc[data.duplicated(subset=['name', 'platform'])][['name', 'platform']]

for name, platform in zip(duplicates['name'], duplicates['platform']): 
    display(data.query('(name  == @name) & (platform == @platform)'))
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 1190  Need for Speed: Most Wanted     X360             2012  Racing      0.62
# 1591  Need for Speed: Most Wanted     X360             2005  Racing      1.00
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 1190      0.78      0.01         0.15          83.0         8.5      T
# 1591      0.13      0.02         0.10          83.0         8.5      T
#
#       sum_sales
# 1190       1.56
# 1591       1.25
#                               name platform  year_of_release   genre  \
# 5972   Need for Speed: Most Wanted       PC             2005  Racing
# 11715  Need for Speed: Most Wanted       PC             2012  Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 5972       0.02      0.23       0.0         0.04          82.0         8.5
# 11715      0.00      0.06       0.0         0.02          82.0         8.5
#
#       rating  sum_sales
# 5972       T       0.29
# 11715      T       0.08
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 604         0.0         0.23          83.0         5.5      E       2.56
# 16230       0.0         0.00          83.0         5.5      E       0.01

# %% [markdown]
# Для игр `Need for Speed: Most Wanted` для платформы `X360` и `Need for Speed: Most Wanted` для `PC` существуют две записи в таблице, у которых различается год выпуска. Возможно, поздние версии игр, выпущенные в 2012 году, являются ремастерами старых, поэтому эти дубликаты лучше не удалять.
#
# Для игры `Madden NFL 13` для платформы `PS3` год выпуска совпадает. Однако, для записи с большим индексом, суммы продаж подозрительно малы, возможно, произошла ошибка при записи данных, поэтому удалим эту строку.

# %%
data.drop(labels = [16230], axis = 0);

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Удалили пропуски в столбцах `year_of_release` и `name`.
# 2. Значения `tbd`в столбце `user_score` заменили на значение `Nan`.
# 3. Изменили тип данных в столбце `year_of_release` на `int`.
# 4. Также заменили тип данных в столбце `user_score` на `float`.
# 5. Не стали заполнять пропуски в столбцах `critic_score` и `user_score`, поскольку на значения в этих столбцах может влиять множество факторов, оценить которые довольно трудно.
# 6. Пропуски в столбце `rating` заполнили строкой 'no_information'.
# 6. Удалили неявные дубликаты.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Выяснить, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %% [markdown]
# Для подсчета числа игр, появившихся в указанный год, не будем учитывать количество платформ, на которых вышла игра.

# %%
data_groupb_year_of_release = data.\
drop_duplicates(subset=['name', 'year_of_release']).groupby(by = 'year_of_release')['name'].count()

data_groupb_year_of_release.plot(grid=True, figsize=(15, 10), 
                                 xticks=data_groupb_year_of_release.index, rot= 45); 
plt.ylabel('Количество игр')
plt.xlabel('Год выпуска')
plt.title('Количество выпущенных игр по годам', fontsize = 17);

# %% [markdown]
# Игры выпущенных до 1993 относительно мало, поэтому можно удалить информацию о них.

# %%
data = data.query('year_of_release >= 1993')

# %% [markdown]
# ### Посмотреть, как менялись продажи по платформам.

# %%
pivot_table_platform_sum_sales = data.pivot_table(index='platform', values='sum_sales', aggfunc='sum').\
sort_values(by='sum_sales', ascending=False) 

pivot_table_platform_sum_sales.plot(kind= 'barh', figsize=(19,15),  rot = -5,legend = False, fontsize = 16).\
set_title('Cумма продаж для каждой платформы' + '\n', fontsize = 21, color = 'Blue');
plt.ylabel('Платформа', fontsize=15)
plt.xlabel('Сумма продаж', fontsize=15);

# %%
platforms_best_sails = pivot_table_platform_sum_sales.head(15).index # 15 лучших платформ по продажам
plt.figure(figsize=(20, 10))
plt.grid(True)
plt.title('График количества продаж 15 платформ с наибольшей суммой продаж по годам', fontsize=20)

count_elements_of_pivote_table = [] 
color_index = 0 
colors = ['black', 'silver', 'firebrick', 'sandybrown', 'gold',
              'olivedrab', 'chartreuse', 'green', 'cyan', 'darkblue', 'coral',
              'orange', 'yellow', 'red', 'greenyellow'] 

for platform in platforms_best_sails:
    platform_sum_sails_per_year = data.query('platform == @platform').\
    pivot_table(index='year_of_release', values='sum_sales', aggfunc='sum') 
    
    count_elements_of_pivote_table.append(platform_sum_sails_per_year.shape[0]) 
    
    plt.plot(platform_sum_sails_per_year, 
             label=platform, alpha=0.7,  marker="o", color=colors[color_index])
    
    color_index +=1
    
plt.legend(title='Платформа', fontsize=14)
plt.xlabel('Год', fontsize=16)
plt.ylabel('Количество продаж', fontsize=16)
print('Среднее время существования платформы среди 15 платформ с наибольшей суммой продаж в годах:', 
      round(np.mean(count_elements_of_pivote_table), 1))
# Out:
# Среднее время существования платформы среди 15 платформ с наибольшей суммой продаж в годах: 9.7

# %% [markdown]
# ### Взять данные за соответствующий актуальный период.

# %% [markdown]
# Предположим, что актуальный период начинается с 2012 года, поскольку по всем платформам, существующим в 2012 году есть данные о продажах в 2016 году. Также корректно учитывать данные по играм в близкий к 2017 году период времени.

# %%
data_actual = data.query('2011 < year_of_release')

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают?

# %%
plt.figure(figsize=(20, 10))
plt.grid(True)
plt.title('График суммы продаж игр по платформам с 2012 года', fontsize=20) 


actual_platform_sum_sails_per_year = data_actual.pivot_table(index=['platform','year_of_release'],
                                                             values='sum_sales', aggfunc='sum').reset_index() 

color_index = 0 # индекс для цвета линий графика
for platform_actual in actual_platform_sum_sails_per_year['platform'].unique():
    
    platform_sum_sails_per_year = actual_platform_sum_sails_per_year.\
    query('platform == @platform_actual')[['year_of_release', 'sum_sales']] 
    
    plt.plot(platform_sum_sails_per_year['year_of_release'], platform_sum_sails_per_year['sum_sales'], 
             label=platform_actual, alpha=0.7,  marker="o", color=colors[color_index])
    color_index += 1
plt.xticks(actual_platform_sum_sails_per_year['year_of_release'].unique())
plt.legend(title='Платформа', fontsize=11)
plt.xlabel('Год', fontsize=16)
plt.ylabel('Сумма продаж', fontsize=16);

# %% [markdown]
# Продажи игр большинства платформ падают с 2013 года.
#
# Продажи игр платформ `PS4` и `XOne` растут с 2013 года по 2015, но в следующие года падают.
#
# Платформы `PS4`, `XOne` и `3DS` можно считать потенциально прибыльными, поскольку у игр данных платформ самые высокие продажи на 2016 год.

# %% [markdown]
# ### Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам

# %%
data_actual_platform = data_actual.groupby('platform')

for name_platform, datas in data_actual_platform:
    print("Платформа " + name_platform)
    print(datas['sum_sales'].describe())
# Out:
# Платформа 3DS
# count    396.000000
# mean       0.491439
# std        1.387161
# min        0.010000
# 25%        0.040000
# 50%        0.110000
# 75%        0.312500
# max       14.600000
# Name: sum_sales, dtype: float64
# Платформа DS
# count    31.000000
# mean      0.404839
# std       1.439245
# min       0.010000
# 25%       0.020000
# 50%       0.050000
# 75%       0.185000
# max       8.060000
# Name: sum_sales, dtype: float64
# Платформа PC
# count    250.00000
# mean       0.25060
# std        0.49464
# min        0.01000
# 25%        0.03000
# 50%        0.08000
# 75%        0.24000
# max        5.14000
# Name: sum_sales, dtype: float64
# Платформа PS3
# count    493.000000
# mean       0.585781
# std        1.462855
# min        0.010000
# 25%        0.050000
# 50%        0.200000
# 75%        0.610000
# max       21.050000
# Name: sum_sales, dtype: float64
# Платформа PS4
# count    392.000000
# mean       0.801378
# std        1.609456
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.730000
# max       14.630000
# Name: sum_sales, dtype: float64
# Платформа PSP
# count    173.000000
# mean       0.064682
# std        0.071296
# min        0.010000
# 25%        0.020000
# 50%        0.030000
# 75%        0.090000
# max        0.360000
# Name: sum_sales, dtype: float64
# Платформа PSV
# count    411.000000
# mean       0.119659
# std        0.203011
# min        0.010000
# 25%        0.020000
# 50%        0.050000
# 75%        0.120000
# max        1.960000
# Name: sum_sales, dtype: float64
# Платформа Wii
# count    54.000000
# mean      0.655000
# std       1.165447
# min       0.010000
# 25%       0.062500
# 50%       0.180000
# 75%       0.687500
# max       6.760000
# Name: sum_sales, dtype: float64
# Платформа WiiU
# count    147.000000
# mean       0.559116
# std        1.058836
# min        0.010000
# 25%        0.080000
# 50%        0.220000
# 75%        0.525000
# max        7.090000
# Name: sum_sales, dtype: float64
# Платформа X360
# count    292.000000
# mean       0.810068
# std        1.712069
# min        0.010000
# 25%        0.100000
# 50%        0.310000
# 75%        0.870000
# max       16.270000
# Name: sum_sales, dtype: float64
# Платформа XOne
# count    247.000000
# mean       0.645020
# std        1.036139
# min        0.010000
# 25%        0.060000
# 50%        0.220000
# 75%        0.685000
# max        7.390000
# Name: sum_sales, dtype: float64

# %%
plt.title('"Графики с усами" для суммарных продаж с разбивкой по платформам')
boxes = sns.boxplot(x='sum_sales', y='platform', data=data_actual, orient='h').set_xlim(0,1)
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи');

# %% [markdown]
# У суммарных продаж игр для платформ `X360` и `PS4`наибольший межквартильный размах, у суммарных продаж игр для платформы `PSP` наименьший межквартильный размах. Большая часть суммарных продаж игр для всех платформ меньше 0.9.

# %%
plt.title('"Графики с усами" для суммарных продаж с разбивкой по платформам')
boxes = sns.boxplot(x='sum_sales', y='platform', data=data_actual, orient='h')
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи');

# %% [markdown]
# У суммарных продаж игр платформ `PS3`, `X360`, `PS4`, `XOne` много выбросов с большим значением `sum_sales` и широкий межквартильный размах.
# У суммарных продаж игры для платформы `Wii` широкий межквартильный размах, но мало выбросов.

# %% [markdown]
# Для всех платформ общая сумма продаж распределена неравномерно, со смещением влево.
#
# 1. Для платформы `3DS` общая сумма продажи большинства игр находится между 0.01 и 0.312.
# 2. Для платформы `DS` общая сумма продажи большинства игр находится между 0.01 и 0.185.
# 3. Для платформы `PC` общая сумма продажи большинства игр находится между 0.01 и 0.24.
# 4. Для платформы `PS3` общая сумма продажи большинства игр находится между 0.01 и 0.61.
# 5. Для платформы `PS4` общая сумма продажи большинства игр находится между 0.01 и 0.73.
# 6. Для платформы `PSP` общая сумма продажи большинства игр находится между 0.01 и 0.09.
# 7. Для платформы `PSV` общая сумма продажи большинства игр находится между 0.01 и 0.12.
# 8. Для платформы `Wii` общая сумма продажи большинства игр находится между 0.01 и 0.687
# 9. Для платформы `WiiU` общая сумма продажи большинства игр находится между 0.01 и 0.525.
# 10. Для платформы `X360` общая сумма продажи большинства игр находится между 0.01 и 0.87.
# 11. Для платформы `XOne` общая сумма продажи большинства игр находится между 0.01 и 0.685.

# %% [markdown]
# ### Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков

# %% [markdown]
# #### Платформа PS4

# %%
data_actual_PS4_user_score = data_actual.query('platform == "PS4"')[['user_score', 'sum_sales']]
data_actual_PS4_user_score.plot(x='user_score', y='sum_sales',
                                kind='scatter', figsize=(10, 7), alpha = 0.7)#диаграмма рассеяния
plt.title('Диаграмма рассеяния зависимости суммы продаж от оценок пользователей для платформы "PS4"')
plt.xlabel('Оценки пользователей')
plt.ylabel('Суммарные продажи');

# %%
print("Коэффициент корреляции Пирсона для колонок sum_sales и user_score", 
      data_actual_PS4_user_score['sum_sales'].corr(data_actual_PS4_user_score['user_score']))
# Out:
# Коэффициент корреляции Пирсона для колонок sum_sales и user_score -0.03195711020455643

# %% [markdown]
# Коэффициент корреляции близок к нулю, что означает, что корреляция практически отсутствует.

# %% [markdown]
# По виду диаграммы рассеяния можно сделать вывод, что при увеличении оценки пользователей, увеличивается количество проданных игр и их суммарная стоимость. Большинство игр имеют оценки пользователей от 5 до 9 из 10.

# %%
data_actual_PS4_critic_score = data_actual.query('platform == "PS4"')[['critic_score', 'sum_sales']]
data_actual_PS4_critic_score.plot(x='critic_score', y='sum_sales',
                                  kind='scatter', figsize=(10, 7), alpha = 0.7)#диаграмма рассеяния
plt.title('Диаграмма рассеяния зависимости суммы продаж от оценок критиков для платформы "PS4"')
plt.xlabel('Оценки критиков')
plt.ylabel('Суммарные продажи');

# %%
print("Коэффициент корреляции Пирсона для колонок sum_sales и critic_score", 
      data_actual_PS4_critic_score['sum_sales'].corr(data_actual_PS4_critic_score['critic_score']))
# Out:
# Коэффициент корреляции Пирсона для колонок sum_sales и critic_score 0.4065679020617816

# %% [markdown]
# Коэффициент корреляции небольшой, поэтому существует несильная прямая зависимость между суммами продаж и оценками критиков для платформы `PS4`.

# %% [markdown]
# По виду диаграммы рассеяния можно сделать вывод, что при увеличении оценки критиков, увеличивается количество проданных игр и их суммарная стоимость. Большинство игр имеют оценки критиков от 60 до 90 из 100.

# %% [markdown]
# #### Платформа XOne

# %%
data_actual_XOne_user_score = data_actual.query('platform == "XOne"')[['user_score', 'sum_sales']]
data_actual_XOne_user_score.plot(x='user_score', y='sum_sales',
                                kind='scatter', figsize=(10, 7), alpha = 0.7)
plt.title('Диаграмма рассеяния зависимости суммы продаж от оценок пользователей для платформы "XOne"')
plt.xlabel('Оценки пользователей')
plt.ylabel('Суммарные продажи');

# %%
print("Коэффициент корреляции Пирсона для колонок sum_sales и user_score", 
      data_actual_XOne_user_score['sum_sales'].corr(data_actual_XOne_user_score['user_score']))
# Out:
# Коэффициент корреляции Пирсона для колонок sum_sales и user_score -0.06892505328279415

# %% [markdown]
# Коэффициент корреляции небольшой, поэтому существует несильная прямая зависимость между суммами продаж и оценками критиков для платформы `XOne`.

# %% [markdown]
# Так же как и для игр для платформы `PS4`, большинство игр для платформы `XOne` имеют оценки пользователей от 5 до 9 из 10.

# %%
data_actual_XOne_critic_score = data_actual.query('platform == "XOne"')[['critic_score', 'sum_sales']]
data_actual_XOne_critic_score.plot(x='critic_score', y='sum_sales',
                                  kind='scatter', figsize=(10, 7), alpha = 0.7)#диаграмма рассеяния
plt.title('Диаграмма рассеяния зависимости суммы продаж от оценок критиков для платформы "XOne"')
plt.xlabel('Оценки критиков')
plt.ylabel('Суммарные продажи');

# %%
print("Коэффициент корреляции Пирсона для колонок sum_sales и critic_score", 
      data_actual_XOne_critic_score['sum_sales'].corr(data_actual_XOne_critic_score['critic_score']))
# Out:
# Коэффициент корреляции Пирсона для колонок sum_sales и critic_score 0.41699832800840164

# %% [markdown]
# Коэффициент корреляции небольшой, поэтому существует несильная прямая зависимость между суммами продаж и оценками критиков для платформы `XOne`.

# %% [markdown]
# По виду диаграммы рассеяния можно сделать вывод, что при увеличении оценки критиков, увеличивается количество проданных игр и их суммарная стоимость. Большинство игр имеют оценки критиков от 70 до 90 из 100.

# %% [markdown]
# #### Платформа 3DS

# %%
data_actual_3DS_user_score = data_actual.query('platform == "3DS"')[['user_score', 'sum_sales']]
data_actual_3DS_user_score.plot(x='user_score', y='sum_sales',
                                kind='scatter', figsize=(10, 7), alpha = 0.7)#диаграмма рассеяния
plt.title('Диаграмма рассеяния зависимости суммы продаж от оценок пользователей для платформы "3DS"')
plt.xlabel('Оценки пользователей')
plt.ylabel('Суммарные продажи');

# %%
print("Коэффициент корреляции Пирсона для колонок sum_sales и user_score", 
      data_actual_3DS_user_score['sum_sales'].corr(data_actual_3DS_user_score['user_score']))
# Out:
# Коэффициент корреляции Пирсона для колонок sum_sales и user_score 0.19758263411038596

# %% [markdown]
# Коэффициент корреляции небольшой, поэтому существует несильная прямая зависимость между суммами продаж и оценками пользователей для платформы `3DS`.

# %% [markdown]
# Так же как и для игр для платформы `PS4`, большинство игр для платформы `3DS` имеют оценки пользователей от 5 до 9 из 10.

# %%
data_actual_3DS_critic_score = data_actual.query('platform == "3DS"')[['critic_score', 'sum_sales']]
data_actual_3DS_critic_score.plot(x='critic_score', y='sum_sales',
                                  kind='scatter', figsize=(10, 7), alpha = 0.7)#диаграмма рассеяния
plt.title('Диаграмма рассеяния зависимости суммы продаж от оценок критиков для платформы "3DS"')
plt.xlabel('Оценки критиков')
plt.ylabel('Суммарные продажи');

# %%
print("Коэффициент корреляции Пирсона для колонок sum_sales и critic_score", 
      data_actual_3DS_critic_score['sum_sales'].corr(data_actual_3DS_critic_score['critic_score']))
# Out:
# Коэффициент корреляции Пирсона для колонок sum_sales и critic_score 0.32080286953607845

# %% [markdown]
# Коэффициент корреляции небольшой, поэтому существует несильная прямая зависимость между суммами продаж и оценками критиков для платформы `3DS`.

# %% [markdown]
# По виду диаграммы рассеяния можно сделать вывод, что при увеличении оценки критиков, увеличивается количество проданных игр и их суммарная стоимость. Большинство игр имеют оценки критиков от 60 до 85 из 100.

# %% [markdown]
# <b>Вывод: </b> Мы сравнили диаграммы рассеяния стоимости игр и оценок пользователей и критиков для трех платформ, они оказались похожи. Логично предположить, что так же, как и для игр на платформах `PS4`, `XOne`, `3DS`, для игр на других платформах, при увеличении оценки пользователей и критиков, увеличивается количество проданных игр и их суммарная стоимость.

# %% [markdown]
# ### Посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах?

# %%
data_actual_pivote = data_actual.pivot_table(index='genre', values='sum_sales', aggfunc='median').\
sort_values(by='sum_sales', ascending=False)

sns.barplot(data=data_actual, x="genre", y="sum_sales", estimator='median', 
            order = data_actual_pivote.reset_index().genre);
plt.xticks(rotation=70)
plt.title('График распределения суммарных продаж по жанрам')
plt.xlabel('Жанры')
plt.ylabel('Суммарные продажи');

# %% [markdown]
# `Shooter` и `Sports` - самые прибыльные жанры. Игры жанров `Adventure`, `Puzzle` приносят меньше всего денег.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Удалили информацию об играх выпущенных до 1993. Изучили, как менялись продажи по платформам. Предположили, что актуальный период начинается с 2012 года.
#
# 2. Продажи игр большинства платформ падают с 2013 года.  Продажи игр платформ `PS4` и `XOne` растут с 2013 года по 2015, но в следующие года падают. Платформы `PS4`, `XOne` и `3DS` можно считать потенциально прибыльными, поскольку у игр данных платформ самые высокие продажи на 2016 год.
#
# 3. У суммарных продаж игр для платформ `X360` и `PS4`наибольший межквартильный размах, у суммарных продаж игр для платформы `PSP` наименьший межквартильный размах. Большая часть суммарных продаж игр для всех платформ меньше 0.9. У суммарных продаж игр платформ `PS3`, `X360`, `PS4`, `XOne` много выбросов с большим значением `sum_sales` и широкий межквартильный размах. У суммарных продаж игры для платформы `Wii` широкий межквартильный размах, но мало выбросов.
#
# 4. Для всех платформ общая сумма продаж распределена неравномерно, со смещением влево.
#
# 5. Мы сравнили диаграммы рассеяния стоимости игр и оценок пользователей и критиков для трех платформ, они оказались похожи. Логично предположить, что так же, как и для игр на платформах `PS4`, `XOne`, `3DS`, для игр на других платформах, при увеличении оценки пользователей и критиков, увеличивается количество проданных игр и их суммарная стоимость.
#
# 6. `Shooter` и `Sports` - самые прибыльные жанры. Игры жанров `Adventure`, `Puzzle` приносят меньше всего денег.

# %% [markdown]
# ## Составить портрет пользователя каждого региона  (NA, EU, JP)

# %% [markdown]
# ### Регион NA

# %%
print('Самые популярные платформы по продажам в NA')
data_actual.pivot_table(index='platform', values='na_sales', aggfunc='sum').\
sort_values(by = 'na_sales', ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# Самые популярные платформы по продажам в NA
# <style type="text/css">
# #T_3878c_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3878c_row1_col0 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_3878c_row2_col0 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_3878c_row3_col0 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_3878c_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_3878c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3878c_level0_col0" class="col_heading level0 col0" >na_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >platform</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3878c_level0_row0" class="row_heading level0 row0" >X360</th>
#       <td id="T_3878c_row0_col0" class="data row0 col0" >140.050000</td>
#     </tr>
#     <tr>
#       <th id="T_3878c_level0_row1" class="row_heading level0 row1" >PS4</th>
#       <td id="T_3878c_row1_col0" class="data row1 col0" >108.740000</td>
#     </tr>
#     <tr>
#       <th id="T_3878c_level0_row2" class="row_heading level0 row2" >PS3</th>
#       <td id="T_3878c_row2_col0" class="data row2 col0" >103.380000</td>
#     </tr>
#     <tr>
#       <th id="T_3878c_level0_row3" class="row_heading level0 row3" >XOne</th>
#       <td id="T_3878c_row3_col0" class="data row3 col0" >93.120000</td>
#     </tr>
#     <tr>
#       <th id="T_3878c_level0_row4" class="row_heading level0 row4" >3DS</th>
#       <td id="T_3878c_row4_col0" class="data row4 col0" >55.310000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Самые популярные платформы в Северной Америке - `X360`и `PS4`, пятая по популярности платформа `3DS`.

# %%
print('Самые популярные жанры по продажам в NA')
data_actual.pivot_table(index='genre', values='na_sales', aggfunc='sum').\
sort_values(by = 'na_sales', ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# Самые популярные жанры по продажам в NA
# <style type="text/css">
# #T_801f1_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_801f1_row1_col0 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_801f1_row2_col0 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_801f1_row3_col0 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_801f1_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_801f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_801f1_level0_col0" class="col_heading level0 col0" >na_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_801f1_level0_row0" class="row_heading level0 row0" >Action</th>
#       <td id="T_801f1_row0_col0" class="data row0 col0" >177.840000</td>
#     </tr>
#     <tr>
#       <th id="T_801f1_level0_row1" class="row_heading level0 row1" >Shooter</th>
#       <td id="T_801f1_row1_col0" class="data row1 col0" >144.770000</td>
#     </tr>
#     <tr>
#       <th id="T_801f1_level0_row2" class="row_heading level0 row2" >Sports</th>
#       <td id="T_801f1_row2_col0" class="data row2 col0" >81.530000</td>
#     </tr>
#     <tr>
#       <th id="T_801f1_level0_row3" class="row_heading level0 row3" >Role-Playing</th>
#       <td id="T_801f1_row3_col0" class="data row3 col0" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_801f1_level0_row4" class="row_heading level0 row4" >Misc</th>
#       <td id="T_801f1_row4_col0" class="data row4 col0" >38.190000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Самый популярный жанр в Северной Америке - `Action`, пятый по популярности жанр - `Misc`.

# %%
sns.scatterplot(data=data_actual, x="rating", y="na_sales", alpha = 0.7)
plt.title('Диаграмма рассеяния зависимости продаж от возрастного рейтинка игр в Северной Америке')
plt.xlabel('Возрастной рейтинг')
plt.ylabel('Продажи')
plt.xticks(rotation=45);

# %%
data_actual.pivot_table(index='rating', values='na_sales', aggfunc='sum').\
sort_values(by='na_sales', ascending=False).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_0af10_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0af10_row1_col0 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_0af10_row2_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_0af10_row3_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_0af10_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0af10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0af10_level0_col0" class="col_heading level0 col0" >na_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rating</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0af10_level0_row0" class="row_heading level0 row0" >M</th>
#       <td id="T_0af10_row0_col0" class="data row0 col0" >231.570000</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row1" class="row_heading level0 row1" >E</th>
#       <td id="T_0af10_row1_col0" class="data row1 col0" >114.370000</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row2" class="row_heading level0 row2" >no_information</th>
#       <td id="T_0af10_row2_col0" class="data row2 col0" >103.310000</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row3" class="row_heading level0 row3" >E10+</th>
#       <td id="T_0af10_row3_col0" class="data row3 col0" >75.700000</td>
#     </tr>
#     <tr>
#       <th id="T_0af10_level0_row4" class="row_heading level0 row4" >T</th>
#       <td id="T_0af10_row4_col0" class="data row4 col0" >66.020000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Больше всего дорогих игр имеют рейтинг `M`, меньше всего дорогих игр в категориях `E10+` и `T`.
#
# Больше всего игр в категориях `M` и `E`, меньше всего - в категории `T`.
#
# Чаще всего люди в Северной Америке покупают игры для платформы `X360` жанра `Action` c рейтингом `M`.

# %% [markdown]
# ### Регион EU

# %%
print('Самые популярные платформы по продажам в EU')
data_actual.pivot_table(index='platform', values='eu_sales', aggfunc='sum').\
sort_values(by = 'eu_sales', ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# Самые популярные платформы по продажам в EU
# <style type="text/css">
# #T_fcfcd_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_fcfcd_row1_col0 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_fcfcd_row2_col0 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_fcfcd_row3_col0 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_fcfcd_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_fcfcd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcfcd_level0_col0" class="col_heading level0 col0" >eu_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >platform</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcfcd_level0_row0" class="row_heading level0 row0" >PS4</th>
#       <td id="T_fcfcd_row0_col0" class="data row0 col0" >141.090000</td>
#     </tr>
#     <tr>
#       <th id="T_fcfcd_level0_row1" class="row_heading level0 row1" >PS3</th>
#       <td id="T_fcfcd_row1_col0" class="data row1 col0" >106.860000</td>
#     </tr>
#     <tr>
#       <th id="T_fcfcd_level0_row2" class="row_heading level0 row2" >X360</th>
#       <td id="T_fcfcd_row2_col0" class="data row2 col0" >74.520000</td>
#     </tr>
#     <tr>
#       <th id="T_fcfcd_level0_row3" class="row_heading level0 row3" >XOne</th>
#       <td id="T_fcfcd_row3_col0" class="data row3 col0" >51.590000</td>
#     </tr>
#     <tr>
#       <th id="T_fcfcd_level0_row4" class="row_heading level0 row4" >3DS</th>
#       <td id="T_fcfcd_row4_col0" class="data row4 col0" >42.640000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Самые популярные платформы в Европе - `PS4` и `PS3`, пятая по популярности платформа - `3DS`.

# %%
print('Самые популярные жанры по продажам в EU')
data_actual.pivot_table(index='genre', values='eu_sales', aggfunc='sum').\
sort_values(by = 'eu_sales', ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# Самые популярные жанры по продажам в EU
# <style type="text/css">
# #T_faa4c_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_faa4c_row1_col0 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_faa4c_row2_col0 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_faa4c_row3_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_faa4c_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_faa4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faa4c_level0_col0" class="col_heading level0 col0" >eu_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faa4c_level0_row0" class="row_heading level0 row0" >Action</th>
#       <td id="T_faa4c_row0_col0" class="data row0 col0" >159.340000</td>
#     </tr>
#     <tr>
#       <th id="T_faa4c_level0_row1" class="row_heading level0 row1" >Shooter</th>
#       <td id="T_faa4c_row1_col0" class="data row1 col0" >113.470000</td>
#     </tr>
#     <tr>
#       <th id="T_faa4c_level0_row2" class="row_heading level0 row2" >Sports</th>
#       <td id="T_faa4c_row2_col0" class="data row2 col0" >69.090000</td>
#     </tr>
#     <tr>
#       <th id="T_faa4c_level0_row3" class="row_heading level0 row3" >Role-Playing</th>
#       <td id="T_faa4c_row3_col0" class="data row3 col0" >48.530000</td>
#     </tr>
#     <tr>
#       <th id="T_faa4c_level0_row4" class="row_heading level0 row4" >Racing</th>
#       <td id="T_faa4c_row4_col0" class="data row4 col0" >27.290000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Самый популярный жанр в Европе - `Action`, пятый по популярности жанр - `Racing`.

# %%
sns.scatterplot(data=data_actual, x="rating", y="eu_sales", alpha = 0.7)
plt.title('Диаграмма рассеяния зависимости продаж от возрастного рейтинка игр в Европе')
plt.xlabel('Возрастной рейтинг')
plt.ylabel('Продажи')
plt.xticks(rotation=45);

# %%
data_actual.pivot_table(index='rating', values='eu_sales', aggfunc='sum').\
sort_values(by='eu_sales', ascending=False).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_3bc0f_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3bc0f_row1_col0 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_3bc0f_row2_col0 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_3bc0f_row3_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_3bc0f_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_3bc0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bc0f_level0_col0" class="col_heading level0 col0" >eu_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rating</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bc0f_level0_row0" class="row_heading level0 row0" >M</th>
#       <td id="T_3bc0f_row0_col0" class="data row0 col0" >193.960000</td>
#     </tr>
#     <tr>
#       <th id="T_3bc0f_level0_row1" class="row_heading level0 row1" >E</th>
#       <td id="T_3bc0f_row1_col0" class="data row1 col0" >113.030000</td>
#     </tr>
#     <tr>
#       <th id="T_3bc0f_level0_row2" class="row_heading level0 row2" >no_information</th>
#       <td id="T_3bc0f_row2_col0" class="data row2 col0" >91.500000</td>
#     </tr>
#     <tr>
#       <th id="T_3bc0f_level0_row3" class="row_heading level0 row3" >E10+</th>
#       <td id="T_3bc0f_row3_col0" class="data row3 col0" >55.370000</td>
#     </tr>
#     <tr>
#       <th id="T_3bc0f_level0_row4" class="row_heading level0 row4" >T</th>
#       <td id="T_3bc0f_row4_col0" class="data row4 col0" >52.960000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Больше всего дорогих игр имеют рейтинг `M`, меньше всего дорогих игр в категориях `E10+` и `T`.
#
# Больше всего игр в категориях `M` и `E`, меньше всего - в категории `T`.
#
# Чаще всего люди в Европе  покупают игры для платформы `PS4` жанра `Action` с рейтингом `M`.

# %% [markdown]
# ### Регион JP

# %%
print('Самые популярные платформы по продажам в JP')
data_actual.pivot_table(index='platform', values='jp_sales', aggfunc='sum').\
sort_values(by = 'jp_sales', ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# Самые популярные платформы по продажам в JP
# <style type="text/css">
# #T_8d8b1_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8d8b1_row1_col0 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_8d8b1_row2_col0 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_8d8b1_row3_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_8d8b1_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8d8b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d8b1_level0_col0" class="col_heading level0 col0" >jp_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >platform</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d8b1_level0_row0" class="row_heading level0 row0" >3DS</th>
#       <td id="T_8d8b1_row0_col0" class="data row0 col0" >87.790000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8b1_level0_row1" class="row_heading level0 row1" >PS3</th>
#       <td id="T_8d8b1_row1_col0" class="data row1 col0" >35.290000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8b1_level0_row2" class="row_heading level0 row2" >PSV</th>
#       <td id="T_8d8b1_row2_col0" class="data row2 col0" >21.040000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8b1_level0_row3" class="row_heading level0 row3" >PS4</th>
#       <td id="T_8d8b1_row3_col0" class="data row3 col0" >15.960000</td>
#     </tr>
#     <tr>
#       <th id="T_8d8b1_level0_row4" class="row_heading level0 row4" >WiiU</th>
#       <td id="T_8d8b1_row4_col0" class="data row4 col0" >13.010000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Самые популярные платформы в Японии - `3DS` и `PS3`, пятая по популярности платформа - `WiiU`.

# %%
print('Самые популярные жанры по продажам в JP')
data_actual.pivot_table(index='genre', values='jp_sales', aggfunc='sum').\
sort_values(by = 'jp_sales', ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# Самые популярные жанры по продажам в JP
# <style type="text/css">
# #T_16e3e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_16e3e_row1_col0 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_16e3e_row2_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_16e3e_row3_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_16e3e_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_16e3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e3e_level0_col0" class="col_heading level0 col0" >jp_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e3e_level0_row0" class="row_heading level0 row0" >Role-Playing</th>
#       <td id="T_16e3e_row0_col0" class="data row0 col0" >65.440000</td>
#     </tr>
#     <tr>
#       <th id="T_16e3e_level0_row1" class="row_heading level0 row1" >Action</th>
#       <td id="T_16e3e_row1_col0" class="data row1 col0" >52.800000</td>
#     </tr>
#     <tr>
#       <th id="T_16e3e_level0_row2" class="row_heading level0 row2" >Misc</th>
#       <td id="T_16e3e_row2_col0" class="data row2 col0" >12.860000</td>
#     </tr>
#     <tr>
#       <th id="T_16e3e_level0_row3" class="row_heading level0 row3" >Simulation</th>
#       <td id="T_16e3e_row3_col0" class="data row3 col0" >10.410000</td>
#     </tr>
#     <tr>
#       <th id="T_16e3e_level0_row4" class="row_heading level0 row4" >Fighting</th>
#       <td id="T_16e3e_row4_col0" class="data row4 col0" >9.440000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Самый популярный жанр в Японии - `Role-Playing`, пятый по популярности жанр - `Fighting`.

# %%
sns.scatterplot(data=data_actual, x="rating", y="jp_sales", alpha = 0.7)
plt.title('Диаграмма рассеяния зависимости продаж от возрастного рейтинка игр в Японии')
plt.xlabel('Возрастной рейтинг')
plt.ylabel('Продажи')
plt.xticks(rotation=45);

# %%
data_actual.pivot_table(index='rating', values='jp_sales', aggfunc='sum').\
sort_values(by='jp_sales', ascending=False).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_e58ba_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e58ba_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_e58ba_row2_col0 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_e58ba_row3_col0 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_e58ba_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_e58ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e58ba_level0_col0" class="col_heading level0 col0" >jp_sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rating</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e58ba_level0_row0" class="row_heading level0 row0" >no_information</th>
#       <td id="T_e58ba_row0_col0" class="data row0 col0" >108.840000</td>
#     </tr>
#     <tr>
#       <th id="T_e58ba_level0_row1" class="row_heading level0 row1" >E</th>
#       <td id="T_e58ba_row1_col0" class="data row1 col0" >28.330000</td>
#     </tr>
#     <tr>
#       <th id="T_e58ba_level0_row2" class="row_heading level0 row2" >T</th>
#       <td id="T_e58ba_row2_col0" class="data row2 col0" >26.020000</td>
#     </tr>
#     <tr>
#       <th id="T_e58ba_level0_row3" class="row_heading level0 row3" >M</th>
#       <td id="T_e58ba_row3_col0" class="data row3 col0" >21.200000</td>
#     </tr>
#     <tr>
#       <th id="T_e58ba_level0_row4" class="row_heading level0 row4" >E10+</th>
#       <td id="T_e58ba_row4_col0" class="data row4 col0" >8.190000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для большой части игр в Японии нет информации об их рейтинге, поэтому оценивать распределение игр по рейтингу довольно сложно.
# Чаще всего люди в Японии  покупают игры для платформы `3DS` жанра `Role-Playing`.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Регион NA:
#     - Больше всего дорогих игр имеют рейтинг `M`, меньше всего дорогих игр в категориях `E10+` и `T`.
#     - Больше всего игр в категориях `M` и `E`, меньше всего - в категории `T`.
#     - Чаще всего люди в Северной Америке покупают игры для платформы `X360` жанра `Action` c рейтингом `M`.
# 2. Регион EU:
#     - Больше всего дорогих игр имеют рейтинг `M`, меньше всего дорогих игр в категориях `E10+` и `T`.
#     - Больше всего игр в категориях `M` и `E`, меньше всего - в категории `T`.
#     - Чаще всего люди в Европе  покупают игры для платформы `PS4` жанра `Action` с рейтингом `M`.
# 3. Регион JP:
#     - Для большой части игр в Японии нет информации об их рейтинге, поэтому оценивать распределение игр по рейтингу довольно сложно.
#     - Чаще всего люди в Японии  покупают игры для платформы `3DS` жанра `Role-Playing`.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1

# %% [markdown]
# H_0: *Средние пользовательские рейтинги платформ Xbox One и PC равны.*
#
# H_1: *Средние пользовательские рейтинги платформ Xbox One и PC не равны.*

# %% [markdown]
# Гипотезу H_0 формулируем, пользуясь условием задания. Гипотезу H_1 получаем при отрицании гипотезы H_0.

# %% [markdown]
# Возьмем случайные 50 значений колонки `user_score` для платформ `XOne` и `PC`.
#
# Используем метод для проверки гипотезы о равенстве среднего двух генеральных совокупностей по взятым из них выборкам: `st.ttest_ind`.
#
# Поскольку количество элементов выборок одинаково, больше 30 и у нас нет оснований предполагать, что дисперсии для выборок отличаются, оставим значение параметра `equal_var` = True.

# %%
not_nan_user_score = ~data_actual['user_score'].isna()

# %%
random_user_score_xone = np.random.choice(data_actual.\
                                          loc[not_nan_user_score].\
                                          query('platform == "XOne"')['user_score'], 
                                          size=50, replace=False)
random_user_score_pc = np.random.choice(data_actual.\
                                        loc[not_nan_user_score].\
                                        query('platform == "PC"')['user_score'], 
                                        size=50, replace=False)

alpha = 0.01 
results = stat.ttest_ind(random_user_score_xone, random_user_score_pc)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.7957390152959858
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Сравнив p-значение с уровнем статистической значимости 0.01, не получилось отвергнуть гипотезу H_0.

# %% [markdown]
# ### Гипотеза 2

# %% [markdown]
# H_0: *Средние пользовательские оценки жанров Action и Sports равны.*
#
# H_1: *Средние пользовательские оценки жанров Action и Sports не равны.*

# %% [markdown]
# Гипотезу H_0 формулируем, пользуясь условием задания. Гипотезу H_1 получаем при отрицании гипотезы H_0.

# %% [markdown]
# Возьмем случайные 50 значений колонки `user_score` для жанров `Action` и `Sports`.
#
# Используем метод для проверки гипотезы о равенстве среднего двух генеральных совокупностей по взятым из них выборкам: `st.ttest_ind`.
#
# Предположим, что дисперсии для выборок отличаются, зададим значение параметра `equal_var` = False.

# %%
random_user_score_action = np.random.choice(data_actual.\
                                            loc[not_nan_user_score].\
                                            query('genre == "Action"')['user_score'], 
                                            size=50, replace=False)

random_user_score_sports = np.random.choice(data_actual.\
                                            loc[not_nan_user_score].\
                                            query('genre == "Sports"')['user_score'], 
                                            size=50, replace=False)

alpha = 0.01 
results = stat.ttest_ind(random_user_score_action, random_user_score_sports, equal_var = False)# проверка гипотезы H_0
print('p-значение:', results.pvalue)

if results.pvalue < alpha: 
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.0049871605713068074
# Отвергаем нулевую гипотезу

# %% [markdown]
# Сравнив p-значение с уровнем статистической значимости 0.01, отвергаем гипотезу H_0.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Гипотезу "Средние пользовательские рейтинги платформ Xbox One и PC равны" не получилось отвергнуть.
# 2. Гипотезу "Средние пользовательские оценки жанров Action и Sports равны" нужно отвергнуть.

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. Начиная с 2008 года количество выпущенных игр падает.
#
# 2. В среднем, игровая платформа существует около 10 лет. Больше всего сумма продаж для игр платформ `PS2` и `X360`.
#
# 3. Платформа `PS4` появилась относительно недавно (2013 г.) и уже стоит на 7 месте по сумме продаж игр в разбивке по платформам.
#
# 4. На 2016 год игры платформ `PS4` и `PS3` лидируют по продажам.
#
# 5. Продажи игр платформ `PS4` и `XOne` растут с 2013 года по 2015, но в следующие года падают. Платформы `PS4`, `XOne` и `3DS` можно считать потенциально прибыльными, поскольку у игр данных платформ самые высокие продажи на 2016 год.
#
# 6. У суммарных продаж игр для платформ `X360` и `PS4`наибольший межквартильный размах, у суммарных продаж игр для платформы `PSP` наименьший межквартильный размах. Большая часть суммарных продаж игр для всех платформ меньше 0.9.
#
# 7. У суммарных продаж игр платформ `PS3`, `X360`, `PS4`, `XOne` много выбросов с большим значением `sum_sales` и широкий межквартильный размах. У суммарных продаж игры для платформы `Wii` широкий межквартильный размах, но мало выбросов.
#
# 8. Логично предположить, что так же, как и для игр на платформах `PS4`, `XOne`, `3DS`, для игр на других платформах, при увеличении оценки пользователей и критиков, увеличивается количество проданных игр и их суммарная стоимость. Больше всего проданных игр с оценками пользователей > 5 и оценками критиков > 60.
#
# 9. `Shooter` и `Sports` - самые прибыльные жанры. Игры жанров `Adventure`, `Puzzle` приносят меньше всего денег.
#
# <b>Совет магазину 1:</b> В первую очередь стоит обратить внимание на игры платформ `PS4` и `XOne`, поскольку эти платформы появились недавно, у игр этих платформ большая сумма продаж, сильный разброс стоимости игр (покупатели с разным финансовым положением смогут купить игру), люди покупают много дорогих игр. Лучше всего продавать игры жанров `Shooter` и `Sports` с оценками пользователей > 5 и оценками критиков > 60.

# %% [markdown]
# 1. Самые популярные платформы в Северной Америке - `X360`и `PS4`, пятая по популярности платформа `3DS`.
# 2. Самый популярный жанр в Северной Америке - `Action`, пятый по популярности жанр - `Misc`.
# 3. Больше всего дорогих игр в Северной Америке имеют рейтинг `M`, меньше всего дорогих игр в категориях `E10+` и `T`. Больше всего игр в категориях `M` и `E`, меньше всего - в категории `T`.
#
# <b>Совет магазину 2:</b> Лучше всего в Северной Америке продавать игры для платформы `X360` и `PS4` жанра `Action` c рейтингом `M`.

# %% [markdown]
# 1. Самые популярные платформы в Европе - `PS4` и `PS3`, пятая по популярности платформа - `3DS`.
# 2. Самый популярный жанр в Европе - `Action`, пятый по популярности жанр - `Racing`.
# 3. Больше всего дорогих игр имеют рейтинг `M`, меньше всего дорогих игр в категориях `E10+` и `T`. Больше всего игр в категориях `M` и `E`, меньше всего - в категории `T`.
#
# <b>Совет магазину 3:</b> Лучше всего в Европе продавать игры для платформ `PS4` и `PS3` жанра `Action` c рейтингом `M`.

# %% [markdown]
# 1. Самые популярные платформы в Японии - `3DS` и `PS3`, пятая по популярности платформа - `WiiU`.
# 2. Самый популярный жанр в Японии - `Role-Playing`, пятый по популярности жанр - `Fighting`.
# 3. Для большой части игр в Японии нет информации об их рейтинге, поэтому оценивать распределение игр по рейтингу довольно сложно.
#
# <b>Совет магазину 4:</b> Лучше всего в Японии продавать игры для платформ `3DS` и `PS3` жанра `Role-Playing`.

# %% [markdown]
# 1. Гипотезу "Средние пользовательские рейтинги платформ Xbox One и PC равны" не получилось отвергнуть.
# 2. Гипотезу "Средние пользовательские оценки жанров Action и Sports равны" нужно отвергнуть.

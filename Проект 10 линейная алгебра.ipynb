# %% [markdown]
# <b>Привет, Виктор!</b>
#
# Меня зовут Харочкина Екатерина, и я буду проверять твой проект. Давай общаться на «ты», но если это неудобно, пожалуйста, сообщи. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе совершенствоваться как профессионалу.
#
# Ты подготовил замечательный проект, но есть аспекты, которые еще можно улучшить. Я буду использовать комментарии с цветовой разметкой. Пожалуйста, **не перемещай, не изменяй и не удаляй их**. Это поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера №1</b> ❌
#
# Таким комментарием выделены самые важные замечания. Без их отработки проект не будет принят.
# </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера №1</b> ⚠️
#
# Таким комментарием выделены небольшие замечания и рекомендации, которые будет хорошо учесть.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера №1</b> ✅
#
# Таким комментарием выделены удачные решения🙂
# </div>
#
# Свои комментарии ты можешь помечать синим цветом.
#
# <div class="alert alert-info">
# <b>Комментарий студента №1</b>
#
# Так ты можешь оформить свой комментарий
# </div>
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. После того, как ты все доработаешь, я смогу принять твой проект!)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Умножение-матриц" data-toc-modified-id="Умножение-матриц-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Умножение матриц</a></span></li><li><span><a href="#Алгоритм-преобразования" data-toc-modified-id="Алгоритм-преобразования-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Алгоритм преобразования</a></span></li><li><span><a href="#Проверка-алгоритма" data-toc-modified-id="Проверка-алгоритма-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка алгоритма</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# # Защита персональных данных клиентов

# %% [markdown]
# Вам нужно защитить данные клиентов страховой компании «Хоть потоп». Разработайте такой метод преобразования данных, чтобы по ним было сложно восстановить персональную информацию. Обоснуйте корректность его работы.
#
# Нужно защитить данные, чтобы при преобразовании качество моделей машинного обучения не ухудшилось. Подбирать наилучшую модель не требуется.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №1</b> ✅
#
# Хорошее начало! С содержанием ориентироваться в проекте намного проще👍 Можно также добавить описание имеющихся данных.
# </div>

# %% [markdown]
# ## Загрузка данных

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
path = '/datasets/insurance.csv'
if os.path.exists(path):
    data = pd.read_csv(path)
else:
    print('Что-то пошло не так')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Пол                5000 non-null   int64
#  1   Возраст            5000 non-null   float64
#  2   Зарплата           5000 non-null   float64
#  3   Члены семьи        5000 non-null   int64
#  4   Страховые выплаты  5000 non-null   int64
# dtypes: float64(2), int64(3)
# memory usage: 195.4 KB

# %%
data.head()
# Out:
#    Пол  Возраст  Зарплата  Члены семьи  Страховые выплаты
# 0    1     41.0   49600.0            1                  0
# 1    0     46.0   38000.0            1                  1
# 2    0     29.0   21000.0            0                  0
# 3    0     21.0   41700.0            2                  0
# 4    1     28.0   26100.0            0                  0

# %%
data.columns = [column.lower() for column in data.columns]

# %%
data = data.rename(columns={'члены семьи': 'члены_семьи', 'страховые выплаты': 'страховые_выплаты'})

# %%
data.isna().sum().sum() # число пропущенных значений
# Out:
# 0

# %%
data.duplicated().sum() # число дубликатов
# Out:
# 153

# %%
data = data.drop_duplicates() # удалили дубликаты

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №1</b> ✅
#
# Так как у нас нет id клиента и у нас мало столбцов и они достаточно общие, поэтому вполне возможно, что это не дубликаты, а просто совпадающие данные
# </div>

# %%
data.describe()
# Out:
#                пол      возраст      зарплата  члены_семьи  страховые_выплаты
# count  4847.000000  4847.000000   4847.000000  4847.000000        4847.000000
# mean      0.498453    31.023932  39895.811842     1.203425           0.152259
# std       0.500049     8.487995   9972.953985     1.098664           0.468934
# min       0.000000    18.000000   5300.000000     0.000000           0.000000
# 25%       0.000000    24.000000  33200.000000     0.000000           0.000000
# 50%       0.000000    30.000000  40200.000000     1.000000           0.000000
# 75%       1.000000    37.000000  46600.000000     2.000000           0.000000
# max       1.000000    65.000000  79000.000000     6.000000           5.000000

# %%
data.corr()# корреляция между столбцами
# Out:
#                         пол   возраст  зарплата  члены_семьи  \
# пол                1.000000  0.001953  0.015456    -0.007315
# возраст            0.001953  1.000000 -0.017386    -0.009064
# зарплата           0.015456 -0.017386  1.000000    -0.031687
# члены_семьи       -0.007315 -0.009064 -0.031687     1.000000
# страховые_выплаты  0.011565  0.654964 -0.013123    -0.039303
#
#                    страховые_выплаты
# пол                         0.011565
# возраст                     0.654964
# зарплата                   -0.013123
# члены_семьи                -0.039303
# страховые_выплаты           1.000000

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера №2</b> ⚠️
#
# Часть признаков в нашем датасете содержат количественные значения, а часть качественные + есть ненормальное распределение, поэтому матрица корреляции Пирсона тут не подходит
# </div>

# %% [markdown]
# Поменяли названия колонок, чтобы они соответствовали стилю snake_case. В данных отсутствуют пропуски. Удалили дубликаты.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №1</b> ✅
#
# Можно еще посмотреть на статистики по столбцам `describe()`. Также, поскольку мы решаем задачу регрессии, хорошо бы посмотреть на корреляции.
# </div>

# %% [markdown]
# ## Умножение матриц

# %% [markdown]
# В этом задании вы можете записывать формулы в *Jupyter Notebook.*
#
# Чтобы записать формулу внутри текста, окружите её символами доллара \\$; если снаружи —  двойными символами \\$\\$. Эти формулы записываются на языке вёрстки *LaTeX.*
#
# Для примера мы записали формулы линейной регрессии. Можете их скопировать и отредактировать, чтобы решить задачу.
#
# Работать в *LaTeX* необязательно.

# %% [markdown]
# Обозначения:
#
# - $X$ — матрица признаков (нулевой столбец состоит из единиц)
#
# - $y$ — вектор целевого признака
#
# - $P$ — матрица, на которую умножаются признаки
#
# - $w$ — вектор весов линейной регрессии (нулевой элемент равен сдвигу)

# %% [markdown]
# Предсказания:
#
#
# $$
# a = Xw
# $$
#
# Задача обучения:
#
# $$
# w = \arg\min_w MSE(Xw, y)
# $$
#
# Формула обучения:
#
# $$
# w = (X^T X)^{-1} X^T y
# $$

# %% [markdown]
# **Ответ:** $w =P^{-1} (X^T X)^{-1} X^T y$
#
#
# **Обоснование:** Пусть $P$ квадратная обратимая матрица. Подставим вместо $X$, $XP$ в $w = (X^T X)^{-1} X^T y$, тогда: $w = ((XP)^T XP)^{-1} (XP)^T y  = (P^T (X^T X) P)^{-1} (XP)^T y = P^{-1} (X^T X)^{-1} (P^T)^{-1} P^T X^T y = P^{-1} (X^T X)^{-1} X^T y$.
#
#
# Подставим $w =P^{-1} (X^T X)^{-1} X^T y$ в $a = XP w$, тогда: $ a = X (X^T X)^{-1} X^T y$.
#
# Подставим $w = (X^T X)^{-1} X^T y $ в $a = Xw$, тогда: $a = X (X^T X)^{-1} X^T y$.
#
# Получаем одинаковые предсказания с преобразованием данных и без него.

# %% [markdown]
# ## Алгоритм преобразования

# %% [markdown]
# **Алгоритм**
# 1. Закодируем матрицу признаков с помощью квадратной обратимой матрицы $P$: $\hat X = XP$, тогда $a = \hat X \omega$.
# 2. Добавляем в $\hat X$ столбец из единиц.
# 3. Пользуясь формулой $w = (X^T X)^{-1} X^T y$ для обучающих данных, находим вектор весов $\omega$.
# 4. Для валидационных данных получим предсказания, пользуясь формулой $a = Xw$.
# 5. Сравниваем значения метрики R2 на валидационных данных для кодированных и некодированных значений.

# %% [markdown]
# **Обоснование**

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера №1</b> ❌
#
# Доказательство верное! Но его надо переместить выше. В пункте 3 нужно описать словами свои дальнейшие действия. Добавь, пожалуйста
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №2</b> ✅
#
# 👍
# </div>

# %% [markdown]
# ## Проверка алгоритма

# %%
target = data['страховые_выплаты']
features = data.drop('страховые_выплаты',axis=1) # признаки без целевого

# %%
np.random.seed(12345)
P = np.random.random((features.shape[1], features.shape[1])) # случайная квадратная матрица P

# %%
np.linalg.det(P) # определитель
# Out:
# -0.05543310984078479

# %% [markdown]
# Определитель матрицы P не равен 0, поэтому она обратима.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №1</b> ✅
#
# Хорошо, что проверяешь матрицу на обратимость
# </div>

# %%
features_cod = features @ P # кодируем признаки

# %%
features_cod.shape
# Out:
# (4847, 4)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера №1</b> ❌
#
# Размер матрицы с закодрованными признаками должен быть равен размеру матрицы изначальных признаков. Матрицу признаков мы умножаем на рандомную матрицу. Для такого умножения количество строк в матрице P должно быть равно количеству столбцов в матрице изначальных признаков. Только после этого мы добавляем нулевой столбец из единиц. Если ты выведешь на экран features_cod, то увидишь, что у нее нулевой столбец не состоит из единиц.
# </div>

# %%
class LinearRegression:
    def fit(self, train_features, train_target): # обучаем модель
        X = np.concatenate((np.ones((train_features.shape[0], 1)), train_features), axis=1)
        y = train_target
        w = np.linalg.inv(X.T @ X) @ X.T @ y
        self.w = w

        
    def predict(self, test_features): # предсказание значений
        return np.concatenate((np.ones((test_features.shape[0], 1)), test_features), axis=1).dot(self.w)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера №1</b> ❌
#
# Класс линейной регрессии нужно будет переписать в соответствии с порядком действий, который я указала в предыдущем комментарии
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №2</b> ✅
#
# 👍
# </div>

# %%
features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, test_size=0.25, random_state=12345)# отделяем 25% данных для обучающей и валидацианной выборки

# %%
features_train_cod, features_valid_cod, target_train, target_valid = train_test_split(
    features_cod, target, test_size=0.25, random_state=12345)# отделяем 5% кодированных данных для обучающей и валидацианной выборки

# %%
model = LinearRegression()
model.fit(features_train, target_train)
predictions = model.predict(features_valid)
r2_usuall = r2_score(target_valid, predictions)
print('Величина R2 для для валидационной выборки линейной регрессии без кодирования данных',r2_usuall)
# Out:
# Величина R2 для для валидационной выборки линейной регрессии без кодирования данных 0.4230772749214827

# %%
model.fit(features_train_cod, target_train)
predictions = model.predict(features_valid_cod)
r2_cod = r2_score(target_valid, predictions)
print('Величина R2 для валидационной выборки линейной регрессии с кодированием данных',r2_cod)
# Out:
# Величина R2 для валидационной выборки линейной регрессии с кодированием данных 0.4230772729876545

# %%
print("Разница величин метрик R2",  r2_usuall - r2_cod)
# Out:
# Разница величин метрик R2 1.9338282086778236e-09

# %% [markdown]
# Судя по значению для метрики R2, модель обучилась на кодированных данных примерно так же как на некодированных.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера №1</b> ❌
#
# Разница из-за неправильной последовательности действий выше
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера №1</b> ✅
#
# Можно также попробовать дешифровать закодированные признаки и сравнить с изначальными признаками
# </div>

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. Был предложен и обоснован алгоритм кодирования данных.
# 2. Найдены значения метрики R2 для линейной регрессии, работающей с кодированными и некодированными данными. Значения метрик немного различаются, что видимо связано с малой вычислительной ошибкой при поиске предсказаний на кодированных и некодированных данных.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий от ревьюера №2**  ✅
#
# Верно, качество предсказания действительно не изменяется. В случае домножения матрицы признаков на случайную обратимую матрицу можно обеспечить защиту данных (Незначительное отличие вызвано особенностью преобразования матриц и чисел с плавающей точкой, это норма. Можно проверить равенство скоров так: `r2_usuall == r2_cod`)
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные загружены
# - [x]  Выполнен шаг 2: получен ответ на вопрос об умножении матриц
#     - [x]  Указан правильный вариант ответа
#     - [x]  Вариант обоснован
# - [x]  Выполнен шаг 3: предложен алгоритм преобразования
#     - [x]  Алгоритм описан
#     - [x]  Алгоритм обоснован
# - [x]  Выполнен шаг 4: алгоритм проверен
#     - [x]  Алгоритм реализован
#     - [x]  Проведено сравнение качества моделей до и после преобразования

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
# <b> <font color='purple' >
#
# Ты хорошо постарался, но проект еще нуждается в доработке. У тебя верное теоретическое доказательство, но над описанием и реализацией алгоритма надо поработать. Обрати внимание на последовательность действий при перемножении матриц. Доделывай и присылай на повторную проверку.
#
# Жду твоих исправлений 😊
# </font></b>
# </div>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
# <b> <font color='purple' >
#
# Отлично! Критических замечаний больше нет. Проект принят! 👏 Поздравляю и желаю удачи!
#
# Оставлю несколько дополнительных материалов. Обзоры по применению криптографии в машинном обучении: https://arxiv.org/pdf/1902.04109.pdf, https://www.researchgate.net/publication/342746786_Some_Applications_of_Machine_Learning_in_Cryptography Подробнее про аналогичный алгоритм: https://www.cs.cmu.edu/~rjhall/JOS_revised_May_31a.pdf
# </font></b>
# </div>
